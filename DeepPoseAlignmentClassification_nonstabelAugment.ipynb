# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image, ImageOps
import os
import json
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms

import torch.optim as optim

import cv2

import random
import numpy as np

import matplotlib.pyplot as plt

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("Running on the GPU")
else:
    device = torch.device("cpu")
    print("Running on the CPU")
# Out:
# Running on the GPU

# %%
RegressionSegmentation = 64
ImageResoulution = 256

# %%
#### DEFINE DataLoader ####
class data(Dataset):
    def ConverPointsToClasses(self, Points):
        classIndexes = Points[:, 0:-1].flatten()
        classIndexes = (classIndexes + 1152) / RegressionSegmentation

        GTsegments = np.zeros((6, RegressionSegmentation))
        for i in range(0, 6):
            idx = int((classIndexes[0, i]))
            if idx < 0 or idx >= RegressionSegmentation:
                return None
            GTsegments[i, int((classIndexes[0, i]))] = 1
        return GTsegments
    
    def __init__(self, path, augment=False):
        self.path = path
        self.files = os.listdir(path)
        self.augment = augment

    # the function returns length of data
    def __len__(self):
        return len(self.files)

    # gives one item at a time
    def __getitem__(self, index):
        convert_tensor = transforms.ToTensor()
        convert_float = transforms.ConvertImageDtype(torch.float)

        DatasetItem = json.load(open(os.path.join(self.path, self.files[index])))
        src = cv2.imread(DatasetItem["src"], cv2.IMREAD_GRAYSCALE)
        dst = cv2.imread(DatasetItem["dst"], cv2.IMREAD_GRAYSCALE)
        originalTransfrom = np.matrix(DatasetItem["transformation"])

        AugmentingMat = None
        if self.augment:
            translationX = random.uniform(80, 150) * random.choice([1, -1])
            translationY = random.uniform(80, 120) * random.choice([1, -1])
            scale = random.uniform(0.8, 1.2)
            rotation = random.uniform(5, 15) * random.choice([1, -1])
            
            AugmentingMat = np.mat([[scale, 0.0, translationX], [0.0, scale, translationY], [0.0, 0.0, 1.0]], dtype=np.float32)
            rotationMat = cv2.getRotationMatrix2D((src.shape[1] // 2, src.shape[0] // 2), rotation, 1)
            AugmentingMat = np.matmul(np.vstack([rotationMat, [0, 0, 1]]), AugmentingMat, dtype=np.float32)

            invertedAugmentingMat = np.mat(cv2.invertAffineTransform(AugmentingMat[0:-1, :]))
            invertedAugmentingMat = np.vstack([invertedAugmentingMat, [0, 0, 1]])

            GeneratedTransform = np.matmul(originalTransfrom, invertedAugmentingMat)
        else:
            GeneratedTransform = originalTransfrom

        points = [
            [0, 0, 1],
            [1440, 1440, 1],
            [0, 1440, 1],
        ]
        warpedPoints = np.matmul(points, GeneratedTransform.transpose(), dtype=np.float32)

        GTsegments = self.ConverPointsToClasses(warpedPoints)
        if GTsegments is not None:
            if AugmentingMat is not None:
                src = cv2.warpAffine(src, AugmentingMat[0:-1, :], (1440, 1440))
            warped = cv2.resize(src, (ImageResoulution, ImageResoulution))
            dst = cv2.resize(dst, (ImageResoulution, ImageResoulution))

            stacked = torch.stack((convert_tensor(dst), convert_tensor(warped)))
            paths = {"src": DatasetItem["src"], "dst": DatasetItem["dst"]}
            return ((stacked, torch.from_numpy(GTsegments.flatten()), paths))
        else:
            GTsegments = self.ConverPointsToClasses(np.mat(points))
            stacked = torch.stack((convert_tensor(dst), convert_tensor(dst)))
            paths = {"src": DatasetItem["dst"], "dst": DatasetItem["dst"]}
            return ((stacked, torch.from_numpy(GTsegments.flatten()), paths))

# %%
#### DEFINE Neural Network ####
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        self._to_linear = None

        # 2 input image channel, 64 output channels, 5x5 square convolution
        # kernel
        self.conv1 = nn.Conv2d(2, 64, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)

        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)

        self.conv5 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)

        self.conv7 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv8 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)

        self.fc9 = nn.Linear(65536, 1024)

        self.fc10 = nn.Linear(1024, RegressionSegmentation * 6)

    def convs(self, x):
        # max pooling over 2x2
        # two conv layers
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))

        # max pooling
        x = F.max_pool2d(x, 2)

        # two conv layers
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))

        # max pooling
        x = F.max_pool2d(x, 2)

        # two conv layers
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))

        # max pooling
        x = F.max_pool2d(x, 2)

        # two conv layers
        x = F.relu(self.conv7(x))
        x = F.relu(self.conv8(x))

        return x

    def forward(self, x):

        x = self.convs(x)
        x = x.view(-1, x[0].shape[0] * x[0].shape[1] * x[0].shape[2])

        # two linear layers
        x = F.relu(self.fc9(x))
        x = self.fc10(x)

        return F.log_softmax(x, dim=1)

# %%
#### Create data ####
trainData = data(".\\..\\data03\MachineData\TrainSet", True)
validationData = data(".\\..\\data03\MachineData\ValidationSet")

# %%
#### Define parameters ####
BatchSize = 8
Epochs = 400
BatchLogCount = 2
LearningRate = 0.00001
WeightDecay = 0.004

# %%
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter(f"runs/DPA_23.3_Class_NotStableAugmentOnly4Pose_v3__LearningRate_{LearningRate}_WeightDecay_{WeightDecay}")

train_dataloader = DataLoader(trainData, batch_size=BatchSize, shuffle=True, drop_last=False)
val_dataloader = DataLoader(validationData, batch_size=BatchSize, shuffle=True, drop_last=False)
net = Net().to(device)
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=LearningRate, weight_decay=WeightDecay)

example_images, example_groundTruths, _ = iter(train_dataloader).next()
writer.add_graph(net, example_images.to(device).view(-1, 2, ImageResoulution, ImageResoulution))

train_set_len = len(trainData)
validation_set_len = len(validationData)
# Learning
running_loss = 0.0
totolBatchCount = 0
for epoch in range(Epochs):
    batchCount = 0
    epoch_loss = 0.0
    for i, dataBatch in enumerate(train_dataloader):
        Images, groundTruths, _ = dataBatch
        Images, groundTruths = Images.to(device), groundTruths.to(device)

        optimizer.zero_grad()

        outputs = net(Images.view(-1, 2, ImageResoulution, ImageResoulution))

        loss = loss_function(outputs, groundTruths.view(-1, RegressionSegmentation * 6))
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        epoch_loss += loss.item()
        batchCount += 1
        totolBatchCount += 1

        if totolBatchCount % BatchLogCount == 0:
            writer.add_scalar("Training loss", running_loss / BatchLogCount, (train_set_len * epoch) + (i * BatchSize))
            running_loss = 0.0

    # Validation
    with torch.no_grad():
        ValidationLoss = 0.0
        ValidationBatchCount = 0
        for k, (Images, groundTruths, _) in enumerate(val_dataloader):
            Images, groundTruths = Images.to(device), groundTruths.to(device)
            outputs = net(Images.view(-1, 2, ImageResoulution, ImageResoulution))
            loss = loss_function(outputs, groundTruths.view(-1, RegressionSegmentation * 6))
            ValidationLoss += loss.item()
            ValidationBatchCount += 1

    writer.add_scalars(f'Loss/Epoch', {
    'Validation loss': ValidationLoss / ValidationBatchCount,
    'Train loss': epoch_loss / batchCount,
    }, epoch)

    # writer.add_scalar("Validation loss / Epoch", ValidationLoss / ValidationBatchCount, epoch)
    # writer.add_scalar("Train loss / Epoch", epoch_loss / batchCount, epoch)

    print(f"Epoch: {epoch}. Train Loss: {epoch_loss / batchCount}")
    print(f"Epoch: {epoch}. Validation Loss: {ValidationLoss / ValidationBatchCount}")
# Out:
# Epoch: 0. Train Loss: 35.6606910392642
# Epoch: 0. Validation Loss: 35.646745800971985
# Epoch: 1. Train Loss: 35.60004474520683
# Epoch: 1. Validation Loss: 35.559954226017
# Epoch: 2. Train Loss: 35.528892648220065
# Epoch: 2. Validation Loss: 35.45245099067688
# Epoch: 3. Train Loss: 35.46108766645193
# Epoch: 3. Validation Loss: 35.355435252189636
# Epoch: 4. Train Loss: 35.3097201064229
# Epoch: 4. Validation Loss: 35.15763507286707
# Epoch: 5. Train Loss: 35.1999745503068
# Epoch: 5. Validation Loss: 35.04104536771774
# Epoch: 6. Train Loss: 35.03536720871925
# Epoch: 6. Validation Loss: 34.77783022324244
# Epoch: 7. Train Loss: 34.850170749425885
# Epoch: 7. Validation Loss: 34.6116289695104
# Epoch: 8. Train Loss: 34.56699397563934
# Epoch: 8. Validation Loss: 34.07903881867727
# Epoch: 9. Train Loss: 34.21534366905689
# Epoch: 9. Validation Loss: 33.809819996356964
# Epoch: 10. Train Loss: 33.75355465263128
# Epoch: 10. Validation Loss: 33.16302623351415
# Epoch: 11. Train Loss: 33.28132867217064
# Epoch: 11. Validation Loss: 32.87566328048706
# Epoch: 12. Train Loss: 32.567357727885245
# Epoch: 12. Validation Loss: 31.737073282400768
# Epoch: 13. Train Loss: 31.93981613814831
# Epoch: 13. Validation Loss: 30.989921549956005
# Epoch: 14. Train Loss: 30.7036383241415
# Epoch: 14. Validation Loss: 29.28258454799652
# Epoch: 15. Train Loss: 30.51196220740676
# Epoch: 15. Validation Loss: 28.75972192486127
# Epoch: 16. Train Loss: 29.997447910904885
# Epoch: 16. Validation Loss: 28.42881555358569
# Epoch: 17. Train Loss: 30.05523664280772
# Epoch: 17. Validation Loss: 28.09832309683164
# Epoch: 18. Train Loss: 29.16136103346944
# Epoch: 18. Validation Loss: 28.469428261121113
# Epoch: 19. Train Loss: 29.67663925215602
# Epoch: 19. Validation Loss: 27.752562512954075
# Epoch: 20. Train Loss: 29.450329726189374
# Epoch: 20. Validation Loss: 27.854721923669178
# Epoch: 21. Train Loss: 29.183774319291114
# Epoch: 21. Validation Loss: 27.448362857103348
# Epoch: 22. Train Loss: 29.126688373088836
# Epoch: 22. Validation Loss: 28.069343268871307
# Epoch: 23. Train Loss: 29.04257763400674
# Epoch: 23. Validation Loss: 27.85434423883756
# Epoch: 24. Train Loss: 28.663239361345767
# Epoch: 24. Validation Loss: 27.375197499990463
# Epoch: 25. Train Loss: 29.329530572146176
# Epoch: 25. Validation Loss: 27.690246164798737
# Epoch: 26. Train Loss: 28.903677355498075
# Epoch: 26. Validation Loss: 28.073652456204098
# Epoch: 27. Train Loss: 28.591674807667733
# Epoch: 27. Validation Loss: 27.85869876543681
# Epoch: 28. Train Loss: 28.623101991415023
# Epoch: 28. Validation Loss: 27.619673162698746
# Epoch: 29. Train Loss: 29.11090987920761
# Epoch: 29. Validation Loss: 27.02356617649396
# Epoch: 30. Train Loss: 28.720796217769383
# Epoch: 30. Validation Loss: 27.292217363913853
# Epoch: 31. Train Loss: 28.895558067411184
# Epoch: 31. Validation Loss: 27.235140293836594
# Epoch: 32. Train Loss: 28.792038187384605
# Epoch: 32. Validation Loss: 27.202009350061417
# Epoch: 33. Train Loss: 28.83555836305022
# Epoch: 33. Validation Loss: 27.102448374032974
# Epoch: 34. Train Loss: 28.748265329748392
# Epoch: 34. Validation Loss: 27.522604922453564
# Epoch: 35. Train Loss: 28.230422139912843
# Epoch: 35. Validation Loss: 27.63319178422292
# Epoch: 36. Train Loss: 29.012804677337407
# Epoch: 36. Validation Loss: 27.35974006851514
# Epoch: 37. Train Loss: 28.766540431976317
# Epoch: 37. Validation Loss: 27.513955225547154
# Epoch: 38. Train Loss: 28.2184543505311
# Epoch: 38. Validation Loss: 27.539589256048203
# Epoch: 39. Train Loss: 28.193020846694708
# Epoch: 39. Validation Loss: 27.295192768176396
# Epoch: 40. Train Loss: 28.395854130387306
# Epoch: 40. Validation Loss: 27.596323152383167
# Epoch: 41. Train Loss: 28.53663009479642
# Epoch: 41. Validation Loss: 27.78008008003235
# Epoch: 42. Train Loss: 28.124552523344754
# Epoch: 42. Validation Loss: 27.55509360631307
# Epoch: 43. Train Loss: 28.56339165866375
# Epoch: 43. Validation Loss: 27.224620441595714
# Epoch: 44. Train Loss: 28.463532658666374
# Epoch: 44. Validation Loss: 27.31838195522626
# Epoch: 45. Train Loss: 28.254643166810276
# Epoch: 45. Validation Loss: 27.188149094581604
# Epoch: 46. Train Loss: 28.612200187146662
# Epoch: 46. Validation Loss: 27.140651027361553
# Epoch: 47. Train Loss: 28.326243359595537
# Epoch: 47. Validation Loss: 28.3026119073232
# Epoch: 48. Train Loss: 28.728931210935116
# Epoch: 48. Validation Loss: 27.3224072655042
# Epoch: 49. Train Loss: 28.326478388905524
# Epoch: 49. Validation Loss: 27.367455770572025
# Epoch: 50. Train Loss: 28.35438387915492
# Epoch: 50. Validation Loss: 27.34386184811592
# Epoch: 51. Train Loss: 28.08840999826789
# Epoch: 51. Validation Loss: 27.222860147555668
# Epoch: 52. Train Loss: 28.162524831295013
# Epoch: 52. Validation Loss: 28.22563444574674
# Epoch: 53. Train Loss: 28.736718464642763
# Epoch: 53. Validation Loss: 27.59275781114896
# Epoch: 54. Train Loss: 28.6098187841475
# Epoch: 54. Validation Loss: 27.536666522423427
# Epoch: 55. Train Loss: 28.21816266775131
# Epoch: 55. Validation Loss: 28.288500756025314
# Epoch: 56. Train Loss: 28.511460857838394
# Epoch: 56. Validation Loss: 27.530165255069733
# Epoch: 57. Train Loss: 28.147415339946747
# Epoch: 57. Validation Loss: 27.68245808283488
# Epoch: 58. Train Loss: 28.244003111124037
# Epoch: 58. Validation Loss: 27.138321310281754
# Epoch: 59. Train Loss: 28.544790702313186
# Epoch: 59. Validation Loss: 27.095506608486176
# Epoch: 60. Train Loss: 28.108443862944842
# Epoch: 60. Validation Loss: 27.807360847791035
# Epoch: 61. Train Loss: 28.588776168227195
# Epoch: 61. Validation Loss: 26.88068229953448
# Epoch: 62. Train Loss: 28.857776833325623
# Epoch: 62. Validation Loss: 27.59542711575826
# Epoch: 63. Train Loss: 28.773192878067494
# Epoch: 63. Validation Loss: 27.174949914216995
# Epoch: 64. Train Loss: 28.205545677244665
# Epoch: 64. Validation Loss: 27.25820764899254
# Epoch: 65. Train Loss: 28.418781378120183
# Epoch: 65. Validation Loss: 26.823460986216862
# Epoch: 66. Train Loss: 28.24850740134716
# Epoch: 66. Validation Loss: 27.26516415675481
# Epoch: 67. Train Loss: 28.66819311156869
# Epoch: 67. Validation Loss: 26.972930639982224
# Epoch: 68. Train Loss: 28.36803197413683
# Epoch: 68. Validation Loss: 27.14440444111824
# Epoch: 69. Train Loss: 28.42070802077651
# Epoch: 69. Validation Loss: 27.275473723808926
# Epoch: 70. Train Loss: 28.44785994961858
# Epoch: 70. Validation Loss: 27.304570704698563
# Epoch: 71. Train Loss: 28.579548202455044
# Epoch: 71. Validation Loss: 26.921320408582687
# Epoch: 72. Train Loss: 28.363582588732243
# Epoch: 72. Validation Loss: 27.557126194238663
# Epoch: 73. Train Loss: 28.492272509634496
# Epoch: 73. Validation Loss: 27.37802090247472
# Epoch: 74. Train Loss: 28.561325573176145
# Epoch: 74. Validation Loss: 27.356290698051453
# Epoch: 75. Train Loss: 28.247003747522832
# Epoch: 75. Validation Loss: 27.26378784577052
# Epoch: 76. Train Loss: 28.47868157699704
# Epoch: 76. Validation Loss: 27.139970819155376
# Epoch: 77. Train Loss: 28.559434043616058
# Epoch: 77. Validation Loss: 26.936526258786518
# Epoch: 78. Train Loss: 28.339478872716427
# Epoch: 78. Validation Loss: 27.144906411568325
# Epoch: 79. Train Loss: 28.344898211956025
# Epoch: 79. Validation Loss: 27.240038851896923
# Epoch: 80. Train Loss: 28.492862264811993
# Epoch: 80. Validation Loss: 26.813518007596333
# Epoch: 81. Train Loss: 28.620185773074628
# Epoch: 81. Validation Loss: 27.24130853017171
# Epoch: 82. Train Loss: 28.389649018645287
# Epoch: 82. Validation Loss: 27.02603778243065
# Epoch: 83. Train Loss: 28.261174409091474
# Epoch: 83. Validation Loss: 27.78879900773366
# Epoch: 84. Train Loss: 28.506879183650017
# Epoch: 84. Validation Loss: 27.529317498207092
# Epoch: 85. Train Loss: 28.20929234549403
# Epoch: 85. Validation Loss: 27.102696379025776
# Epoch: 86. Train Loss: 27.947989469021557
# Epoch: 86. Validation Loss: 27.07101661960284
# Epoch: 87. Train Loss: 28.722943710535766
# Epoch: 87. Validation Loss: 26.98156252503395
# Epoch: 88. Train Loss: 28.19600900709629
# Epoch: 88. Validation Loss: 27.374669929345448
# Epoch: 89. Train Loss: 28.391253273934126
# Epoch: 89. Validation Loss: 26.96224444111188
# Epoch: 90. Train Loss: 28.68522266820073
# Epoch: 90. Validation Loss: 27.205003052949905
# Epoch: 91. Train Loss: 28.243838316202165
# Epoch: 91. Validation Loss: 27.02347206075986
# Epoch: 92. Train Loss: 28.432197181135415
# Epoch: 92. Validation Loss: 27.579774449268978
# Epoch: 93. Train Loss: 28.572558253258467
# Epoch: 93. Validation Loss: 26.91271518667539
# Epoch: 94. Train Loss: 28.576746033132075
# Epoch: 94. Validation Loss: 27.002785285313923
# Epoch: 95. Train Loss: 28.480519775301218
# Epoch: 95. Validation Loss: 27.722562472025555
# Epoch: 96. Train Loss: 28.243576253950597
# Epoch: 96. Validation Loss: 28.216792931159336
# Epoch: 97. Train Loss: 28.583910715579986
# Epoch: 97. Validation Loss: 27.45672146479289
# Epoch: 98. Train Loss: 27.987853492051364
# Epoch: 98. Validation Loss: 27.92304726441701
# Epoch: 99. Train Loss: 28.262177246809006
# Epoch: 99. Validation Loss: 27.442317247390747
# Epoch: 100. Train Loss: 28.22012477889657
# Epoch: 100. Validation Loss: 27.05094952384631
# Epoch: 101. Train Loss: 28.11208272278309
# Epoch: 101. Validation Loss: 27.008978972832363
# Epoch: 102. Train Loss: 28.161181024461985
# Epoch: 102. Validation Loss: 27.03637307882309
# Epoch: 103. Train Loss: 28.767247831076382
# Epoch: 103. Validation Loss: 27.053782651821773
# Epoch: 104. Train Loss: 28.290676660835743
# Epoch: 104. Validation Loss: 27.658852100372314
# Epoch: 105. Train Loss: 28.2848789639771
# Epoch: 105. Validation Loss: 27.320634255806606
# Epoch: 106. Train Loss: 28.224102202802896
# Epoch: 106. Validation Loss: 27.117116669813793
# Epoch: 107. Train Loss: 28.53847506120801
# Epoch: 107. Validation Loss: 27.227432479461033
# Epoch: 108. Train Loss: 28.73448460251093
# Epoch: 108. Validation Loss: 27.280476570129395
# Epoch: 109. Train Loss: 28.277784847468137
# Epoch: 109. Validation Loss: 27.252370585997898
# Epoch: 110. Train Loss: 28.453838080912828
# Epoch: 110. Validation Loss: 27.04717958966891
# Epoch: 111. Train Loss: 28.3480333596468
# Epoch: 111. Validation Loss: 27.74661632378896
# Epoch: 112. Train Loss: 28.38204877898097
# Epoch: 112. Validation Loss: 27.00015538930893
# Epoch: 113. Train Loss: 27.97274267747998
# Epoch: 113. Validation Loss: 26.97482019662857
# Epoch: 114. Train Loss: 27.90245972648263
# Epoch: 114. Validation Loss: 27.529411415259045
# Epoch: 115. Train Loss: 28.291306390613318
# Epoch: 115. Validation Loss: 26.876850614945095
# Epoch: 116. Train Loss: 28.07985974177718
# Epoch: 116. Validation Loss: 26.52877613902092
# Epoch: 117. Train Loss: 28.16911722943187
# Epoch: 117. Validation Loss: 27.658482591311138
# Epoch: 118. Train Loss: 28.33730031400919
# Epoch: 118. Validation Loss: 26.637045602003735
# Epoch: 119. Train Loss: 28.252386324107647
# Epoch: 119. Validation Loss: 27.673028339942295
# Epoch: 120. Train Loss: 28.46941282376647
# Epoch: 120. Validation Loss: 26.87271613876025
# Epoch: 121. Train Loss: 28.37785315811634
# Epoch: 121. Validation Loss: 27.12324466307958
# Epoch: 122. Train Loss: 28.4466503046453
# Epoch: 122. Validation Loss: 28.277951429287594
# Epoch: 123. Train Loss: 28.36813430413604
# Epoch: 123. Validation Loss: 27.092045575380325
# Epoch: 124. Train Loss: 27.982789377868176
# Epoch: 124. Validation Loss: 27.04042759537697
# Epoch: 125. Train Loss: 28.012320551276208
# Epoch: 125. Validation Loss: 27.255625426769257
# Epoch: 126. Train Loss: 28.356033143401145
# Epoch: 126. Validation Loss: 27.35080275932948
# Epoch: 127. Train Loss: 28.498127041757108
# Epoch: 127. Validation Loss: 26.872147897879284
# Epoch: 128. Train Loss: 27.96654541864991
# Epoch: 128. Validation Loss: 26.933593173821766
# Epoch: 129. Train Loss: 28.400146735459565
# Epoch: 129. Validation Loss: 27.309306502342224
# Epoch: 130. Train Loss: 28.387990298867226
# Epoch: 130. Validation Loss: 27.060791462659836
# Epoch: 131. Train Loss: 28.202845914661886
# Epoch: 131. Validation Loss: 26.991735498110454
# Epoch: 132. Train Loss: 28.10589335784316
# Epoch: 132. Validation Loss: 26.733655482530594
# Epoch: 133. Train Loss: 28.093180739879607
# Epoch: 133. Validation Loss: 26.575931906700134
# Epoch: 134. Train Loss: 28.154027797281742
# Epoch: 134. Validation Loss: 27.235200772682827
# Epoch: 135. Train Loss: 28.412645550817253
# Epoch: 135. Validation Loss: 26.652750353018444
# Epoch: 136. Train Loss: 28.207753747701645
# Epoch: 136. Validation Loss: 26.947437087694805
# Epoch: 137. Train Loss: 28.113278387486936
# Epoch: 137. Validation Loss: 27.60144352912903
# Epoch: 138. Train Loss: 28.069140376150607
# Epoch: 138. Validation Loss: 27.076146731774013
# Epoch: 139. Train Loss: 28.11017453446984
# Epoch: 139. Validation Loss: 26.81475826104482
# Epoch: 140. Train Loss: 27.861934567242862
# Epoch: 140. Validation Loss: 26.841557532548904
# Epoch: 141. Train Loss: 28.07812933921814
# Epoch: 141. Validation Loss: 26.839961022138596
# Epoch: 142. Train Loss: 27.974469704926015
# Epoch: 142. Validation Loss: 26.92849346001943
# Epoch: 143. Train Loss: 28.05579848960042
# Epoch: 143. Validation Loss: 26.52322906255722
# Epoch: 144. Train Loss: 28.22613870203495
# Epoch: 144. Validation Loss: 26.849115520715714
# Epoch: 145. Train Loss: 27.835697885602713
# Epoch: 145. Validation Loss: 27.443051864703495
# Epoch: 146. Train Loss: 28.4158606402576
# Epoch: 146. Validation Loss: 26.974736084540684
# Epoch: 147. Train Loss: 27.824097415804864
# Epoch: 147. Validation Loss: 27.938965608676273
# Epoch: 148. Train Loss: 28.32251379713416
# Epoch: 148. Validation Loss: 26.915375113487244
# Epoch: 149. Train Loss: 27.999022462964057
# Epoch: 149. Validation Loss: 27.663065145413082
# Epoch: 150. Train Loss: 27.717414170503616
# Epoch: 150. Validation Loss: 26.86019667983055
# Epoch: 151. Train Loss: 27.9628898024559
# Epoch: 151. Validation Loss: 27.346553802490234
# Epoch: 152. Train Loss: 27.908064372092486
# Epoch: 152. Validation Loss: 27.740251769622166
# Epoch: 153. Train Loss: 27.810122737288474
# Epoch: 153. Validation Loss: 27.419633716344833
# Epoch: 154. Train Loss: 27.77401181384921
# Epoch: 154. Validation Loss: 28.381913403669994
# Epoch: 155. Train Loss: 27.58231014981866
# Epoch: 155. Validation Loss: 28.592972298463184
# Epoch: 156. Train Loss: 28.122924047708512
# Epoch: 156. Validation Loss: 27.865467091401417
# Epoch: 157. Train Loss: 27.620950907468796
# Epoch: 157. Validation Loss: 27.10588629047076
# Epoch: 158. Train Loss: 27.977500188350678
# Epoch: 158. Validation Loss: 27.196735481421154
# Epoch: 159. Train Loss: 27.863824785500764
# Epoch: 159. Validation Loss: 26.677355378866196
# Epoch: 160. Train Loss: 27.408118319511413
# Epoch: 160. Validation Loss: 27.18375367919604
# Epoch: 161. Train Loss: 27.44230922460556
# Epoch: 161. Validation Loss: 27.80450517932574
# Epoch: 162. Train Loss: 27.093850942701103
# Epoch: 162. Validation Loss: 27.141304512818653
# Epoch: 163. Train Loss: 27.46611556261778
# Epoch: 163. Validation Loss: 26.841783553361893
# Epoch: 164. Train Loss: 27.764703599363564
# Epoch: 164. Validation Loss: 26.418751974900562
# Epoch: 165. Train Loss: 27.19577049165964
# Epoch: 165. Validation Loss: 26.781501164038975
# Epoch: 166. Train Loss: 27.671517219394445
# Epoch: 166. Validation Loss: 27.522685925165813
# Epoch: 167. Train Loss: 27.307263519614935
# Epoch: 167. Validation Loss: 27.004857907692593
# Epoch: 168. Train Loss: 27.649943438917397
# Epoch: 168. Validation Loss: 27.152894993623097
# Epoch: 169. Train Loss: 27.404256664961576
# Epoch: 169. Validation Loss: 26.88136903444926
# Epoch: 170. Train Loss: 26.957822801917793
# Epoch: 170. Validation Loss: 26.78351895014445
# Epoch: 171. Train Loss: 26.914474514871834
# Epoch: 171. Validation Loss: 26.70032439629237
# Epoch: 172. Train Loss: 27.35550746321678
# Epoch: 172. Validation Loss: 27.09887557228406
# Epoch: 173. Train Loss: 27.34040001183748
# Epoch: 173. Validation Loss: 26.799791673819225
# Epoch: 174. Train Loss: 26.893328657746316
# Epoch: 174. Validation Loss: 27.88901014129321
# Epoch: 175. Train Loss: 27.685585843771698
# Epoch: 175. Validation Loss: 26.767658700545628
# Epoch: 176. Train Loss: 27.567238911241294
# Epoch: 176. Validation Loss: 27.403332541386288
# Epoch: 177. Train Loss: 27.29095225632191
# Epoch: 177. Validation Loss: 27.498004655043285
# Epoch: 178. Train Loss: 27.323228295892477
# Epoch: 178. Validation Loss: 26.630316774050396
# Epoch: 179. Train Loss: 26.632061644643546
# Epoch: 179. Validation Loss: 26.92765478293101
# Epoch: 180. Train Loss: 27.630730387568473
# Epoch: 180. Validation Loss: 26.94968248407046
# Epoch: 181. Train Loss: 27.069093788415195
# Epoch: 181. Validation Loss: 26.576323519150417
# Epoch: 182. Train Loss: 26.62577668726444
# Epoch: 182. Validation Loss: 26.765307704607647
# Epoch: 183. Train Loss: 26.985142845660448
# Epoch: 183. Validation Loss: 27.082314362128574
# Epoch: 184. Train Loss: 27.134244687855244
# Epoch: 184. Validation Loss: 27.37329602241516
# Epoch: 185. Train Loss: 26.654245249181987
# Epoch: 185. Validation Loss: 27.324869126081467
# Epoch: 186. Train Loss: 27.37769367918372
# Epoch: 186. Validation Loss: 26.9937508503596
# Epoch: 187. Train Loss: 27.354353243112563
# Epoch: 187. Validation Loss: 26.697457124789555
# Epoch: 188. Train Loss: 26.782607529312372
# Epoch: 188. Validation Loss: 27.14374965429306
# Epoch: 189. Train Loss: 26.961021973192693
# Epoch: 189. Validation Loss: 26.985870609680813
# Epoch: 190. Train Loss: 27.039628133922815
# Epoch: 190. Validation Loss: 27.77705372373263
# Epoch: 191. Train Loss: 27.021187241375447
# Epoch: 191. Validation Loss: 26.510022630294163
# Epoch: 192. Train Loss: 27.03366462737322
# Epoch: 192. Validation Loss: 26.417375564575195
# Epoch: 193. Train Loss: 26.92377284541726
# Epoch: 193. Validation Loss: 26.87031430999438
# Epoch: 194. Train Loss: 26.908870029449464
# Epoch: 194. Validation Loss: 26.915516565243404
# Epoch: 195. Train Loss: 27.012515471875666
# Epoch: 195. Validation Loss: 27.428339292605717
# Epoch: 196. Train Loss: 26.473081343621015
# Epoch: 196. Validation Loss: 27.543637951215107
# Epoch: 197. Train Loss: 26.849690033495428
# Epoch: 197. Validation Loss: 26.769255956013996
# Epoch: 198. Train Loss: 26.5692415073514
# Epoch: 198. Validation Loss: 27.394657492637634
# Epoch: 199. Train Loss: 26.677931344509126
# Epoch: 199. Validation Loss: 27.69992130001386
# Epoch: 200. Train Loss: 26.97431664317846
# Epoch: 200. Validation Loss: 26.207078019777935
# Epoch: 201. Train Loss: 27.3030144572258
# Epoch: 201. Validation Loss: 26.625533640384674
# Epoch: 202. Train Loss: 26.730496621876956
# Epoch: 202. Validation Loss: 25.980613470077515
# Epoch: 203. Train Loss: 26.64103150293231
# Epoch: 203. Validation Loss: 26.552660306294758
# Epoch: 204. Train Loss: 27.01297731846571
# Epoch: 204. Validation Loss: 26.990075359741848
# Epoch: 205. Train Loss: 26.38264792636037
# Epoch: 205. Validation Loss: 26.664830833673477
# Epoch: 206. Train Loss: 26.79241893813014
# Epoch: 206. Validation Loss: 26.94814591606458
# Epoch: 207. Train Loss: 26.963231606036423
# Epoch: 207. Validation Loss: 26.56606697042783
# Epoch: 208. Train Loss: 26.83437990322709
# Epoch: 208. Validation Loss: 26.902223308881123
# Epoch: 209. Train Loss: 26.837731548398732
# Epoch: 209. Validation Loss: 27.694132804870605
# Epoch: 210. Train Loss: 26.410795179754494
# Epoch: 210. Validation Loss: 26.494379897912342
# Epoch: 211. Train Loss: 26.523917032033204
# Epoch: 211. Validation Loss: 26.70757516225179
# Epoch: 212. Train Loss: 26.56370838806033
# Epoch: 212. Validation Loss: 27.727961500485737
# Epoch: 213. Train Loss: 26.57087396159768
# Epoch: 213. Validation Loss: 26.43341200550397
# Epoch: 214. Train Loss: 26.395709479600193
# Epoch: 214. Validation Loss: 26.719487686951954
# Epoch: 215. Train Loss: 26.38505311757326
# Epoch: 215. Validation Loss: 27.062344640493393
# Epoch: 216. Train Loss: 26.380446308106183
# Epoch: 216. Validation Loss: 26.526364475488663
# Epoch: 217. Train Loss: 26.705314016342165
# Epoch: 217. Validation Loss: 26.06492906808853
# Epoch: 218. Train Loss: 26.806741470843555
# Epoch: 218. Validation Loss: 26.46816611289978
# Epoch: 219. Train Loss: 26.26373483091593
# Epoch: 219. Validation Loss: 26.603272289037704
# Epoch: 220. Train Loss: 26.598087814450263
# Epoch: 220. Validation Loss: 26.536969085534412
# Epoch: 221. Train Loss: 26.8121555775404
# Epoch: 221. Validation Loss: 26.632535854975384
# Epoch: 222. Train Loss: 26.802931509912014
# Epoch: 222. Validation Loss: 27.026721100012463
# Epoch: 223. Train Loss: 26.382877858728172
# Epoch: 223. Validation Loss: 26.75010324517886
# Epoch: 224. Train Loss: 26.211386878043413
# Epoch: 224. Validation Loss: 27.39050571123759
# Epoch: 225. Train Loss: 26.15704475939274
# Epoch: 225. Validation Loss: 26.102319677670796
# Epoch: 226. Train Loss: 26.262781772762537
# Epoch: 226. Validation Loss: 27.550930341084797
# Epoch: 227. Train Loss: 26.693875532597303
# Epoch: 227. Validation Loss: 26.653804262479145
# Epoch: 228. Train Loss: 26.621138569712638
# Epoch: 228. Validation Loss: 26.240074912707012
# Epoch: 229. Train Loss: 27.046659219264985
# Epoch: 229. Validation Loss: 26.860487471024197
# Epoch: 230. Train Loss: 26.01273128092289
# Epoch: 230. Validation Loss: 26.507960379123688
# Epoch: 231. Train Loss: 26.286717454344036
# Epoch: 231. Validation Loss: 26.36071303486824
# Epoch: 232. Train Loss: 26.15410901606083
# Epoch: 232. Validation Loss: 26.674356172482174
# Epoch: 233. Train Loss: 26.251165437698365
# Epoch: 233. Validation Loss: 26.164933532476425
# Epoch: 234. Train Loss: 26.089880122989417
# Epoch: 234. Validation Loss: 26.09166956941287
# Epoch: 235. Train Loss: 26.063036374747753
# Epoch: 235. Validation Loss: 26.693617790937424
# Epoch: 236. Train Loss: 25.78366137854755
# Epoch: 236. Validation Loss: 27.21703663468361
# Epoch: 237. Train Loss: 26.224421396106482
# Epoch: 237. Validation Loss: 26.31138187646866
# Epoch: 238. Train Loss: 26.548454421758652
# Epoch: 238. Validation Loss: 26.9780952334404
# Epoch: 239. Train Loss: 26.88826351799071
# Epoch: 239. Validation Loss: 26.634318282206852
# Epoch: 240. Train Loss: 26.155461683869362
# Epoch: 240. Validation Loss: 26.446057428916294
# Epoch: 241. Train Loss: 26.420454565435648
# Epoch: 241. Validation Loss: 26.154076099395752
# Epoch: 242. Train Loss: 26.406740388274194
# Epoch: 242. Validation Loss: 26.183265288670857
# Epoch: 243. Train Loss: 26.123297776281834
# Epoch: 243. Validation Loss: 26.742045054833095
# Epoch: 244. Train Loss: 26.43188622742891
# Epoch: 244. Validation Loss: 26.43664206067721
# Epoch: 245. Train Loss: 26.3743098244071
# Epoch: 245. Validation Loss: 25.542679230372112
# Epoch: 246. Train Loss: 26.17607175260782
# Epoch: 246. Validation Loss: 26.056713938713074
# Epoch: 247. Train Loss: 26.53707686215639
# Epoch: 247. Validation Loss: 25.504925062259037
# Epoch: 248. Train Loss: 26.542886766046287
# Epoch: 248. Validation Loss: 26.54841082294782
# Epoch: 249. Train Loss: 26.738847798109056
# Epoch: 249. Validation Loss: 26.901530752579372
# Epoch: 250. Train Loss: 26.02198908999562
# Epoch: 250. Validation Loss: 26.299412151177723
# Epoch: 251. Train Loss: 25.71996719762683
# Epoch: 251. Validation Loss: 26.060191373030346
# Epoch: 252. Train Loss: 26.33674510419369
# Epoch: 252. Validation Loss: 26.071056207021076
# Epoch: 253. Train Loss: 25.864872167259456
# Epoch: 253. Validation Loss: 27.01807729403178
# Epoch: 254. Train Loss: 25.93272837996483
# Epoch: 254. Validation Loss: 26.846889704465866
# Epoch: 255. Train Loss: 26.313389760255813
# Epoch: 255. Validation Loss: 26.088429758946102
# Epoch: 256. Train Loss: 25.946119437366725
# Epoch: 256. Validation Loss: 26.187722235918045
# Epoch: 257. Train Loss: 25.889047583192585
# Epoch: 257. Validation Loss: 26.63218802213669
# Epoch: 258. Train Loss: 25.823795988410712
# Epoch: 258. Validation Loss: 26.520973374446232
# Epoch: 259. Train Loss: 25.463605308532713
# Epoch: 259. Validation Loss: 28.03491962949435
# Epoch: 260. Train Loss: 25.688538088649512
# Epoch: 260. Validation Loss: 25.984838863213856
# Epoch: 261. Train Loss: 26.20769885852933
# Epoch: 261. Validation Loss: 25.923097451527912
# Epoch: 262. Train Loss: 26.226855866611004
# Epoch: 262. Validation Loss: 25.893905848264694
# Epoch: 263. Train Loss: 25.972824116796254
# Epoch: 263. Validation Loss: 26.193973044554394
# Epoch: 264. Train Loss: 25.837654070556162
# Epoch: 264. Validation Loss: 26.077064643303554
# Epoch: 265. Train Loss: 25.627174826711418
# Epoch: 265. Validation Loss: 26.097148875395458
# Epoch: 266. Train Loss: 26.301904243975876
# Epoch: 266. Validation Loss: 27.49725027879079
# Epoch: 267. Train Loss: 26.091996275633573
# Epoch: 267. Validation Loss: 26.730635861555736
# Epoch: 268. Train Loss: 26.123468606173994
# Epoch: 268. Validation Loss: 27.36241791645686
# Epoch: 269. Train Loss: 25.66964219212532
# Epoch: 269. Validation Loss: 26.827738145987194
# Epoch: 270. Train Loss: 26.45241138637066
# Epoch: 270. Validation Loss: 26.793158322572708
# Epoch: 271. Train Loss: 25.933318150788544
# Epoch: 271. Validation Loss: 26.787132402261097
# Epoch: 272. Train Loss: 26.010339529812335
# Epoch: 272. Validation Loss: 26.030773381392162
# Epoch: 273. Train Loss: 25.77978570535779
# Epoch: 273. Validation Loss: 26.248440504074097
# Epoch: 274. Train Loss: 26.007896918058396
# Epoch: 274. Validation Loss: 26.29094699025154
# Epoch: 275. Train Loss: 26.037826877087355
# Epoch: 275. Validation Loss: 26.47399229804675
# Epoch: 276. Train Loss: 25.93354815170169
# Epoch: 276. Validation Loss: 26.33751666545868
# Epoch: 277. Train Loss: 25.823339004814624
# Epoch: 277. Validation Loss: 26.470815519491833
# Epoch: 278. Train Loss: 25.926675543934106
# Epoch: 278. Validation Loss: 25.955196966727573
# Epoch: 279. Train Loss: 25.77883731164038
# Epoch: 279. Validation Loss: 26.388870060443878
# Epoch: 280. Train Loss: 26.415777188539504
# Epoch: 280. Validation Loss: 26.343787372112274
# Epoch: 281. Train Loss: 25.845781905949117
# Epoch: 281. Validation Loss: 26.88876756032308
# Epoch: 282. Train Loss: 25.997036477923395
# Epoch: 282. Validation Loss: 26.98211418588956
# Epoch: 283. Train Loss: 26.300003024935723
# Epoch: 283. Validation Loss: 26.627098103364307
# Epoch: 284. Train Loss: 25.618952033668755
# Epoch: 284. Validation Loss: 26.495989461739857
# Epoch: 285. Train Loss: 25.91840688213706
# Epoch: 285. Validation Loss: 27.444300095240276
# Epoch: 286. Train Loss: 25.514601754397155
# Epoch: 286. Validation Loss: 26.523981134096783
# Epoch: 287. Train Loss: 25.611476092785598
# Epoch: 287. Validation Loss: 26.938641985257465
# Epoch: 288. Train Loss: 25.936983542144297
# Epoch: 288. Validation Loss: 26.553002138932545
# Epoch: 289. Train Loss: 25.718545623123646
# Epoch: 289. Validation Loss: 27.050054053465526
# Epoch: 290. Train Loss: 25.583992984890937
# Epoch: 290. Validation Loss: 27.808076242605846
# Epoch: 291. Train Loss: 26.054314469546078
# Epoch: 291. Validation Loss: 26.751695553461712
# Epoch: 292. Train Loss: 25.825549752265214
# Epoch: 292. Validation Loss: 27.376087884108227
# Epoch: 293. Train Loss: 26.09502733051777
# Epoch: 293. Validation Loss: 26.162132720152538
# Epoch: 294. Train Loss: 25.346671332418918
# Epoch: 294. Validation Loss: 26.248578389485676
# Epoch: 295. Train Loss: 25.647564185410737
# Epoch: 295. Validation Loss: 26.667880813280743
# Epoch: 296. Train Loss: 25.936873852461577
# Epoch: 296. Validation Loss: 25.75194326043129
# Epoch: 297. Train Loss: 25.677841406315565
# Epoch: 297. Validation Loss: 26.855004638433456
# Epoch: 298. Train Loss: 25.74746779128909
# Epoch: 298. Validation Loss: 25.92571281393369
# Epoch: 299. Train Loss: 25.979655792564152
# Epoch: 299. Validation Loss: 26.159966856241226
# Epoch: 300. Train Loss: 25.60429195985198
# Epoch: 300. Validation Loss: 27.303904314835865
# Epoch: 301. Train Loss: 25.928840359300374
# Epoch: 301. Validation Loss: 25.872640649477642
# Epoch: 302. Train Loss: 25.252660398185252
# Epoch: 302. Validation Loss: 27.278646379709244
# Epoch: 303. Train Loss: 25.60617782920599
# Epoch: 303. Validation Loss: 26.528162827094395
# Epoch: 304. Train Loss: 26.02462599799037
# Epoch: 304. Validation Loss: 26.92160928249359
# Epoch: 305. Train Loss: 25.953763496130705
# Epoch: 305. Validation Loss: 26.576119393110275
# Epoch: 306. Train Loss: 25.377625375241042
# Epoch: 306. Validation Loss: 26.91904346148173
# Epoch: 307. Train Loss: 25.62803529202938
# Epoch: 307. Validation Loss: 26.39027140537898
# Epoch: 308. Train Loss: 25.671346858888864
# Epoch: 308. Validation Loss: 26.15370750427246
# Epoch: 309. Train Loss: 25.898827517032622
# Epoch: 309. Validation Loss: 26.052971015373867
# Epoch: 310. Train Loss: 25.441590877622367
# Epoch: 310. Validation Loss: 28.090841839710873
# Epoch: 311. Train Loss: 25.7195241458714
# Epoch: 311. Validation Loss: 27.533334851264954
# Epoch: 312. Train Loss: 25.3349539488554
# Epoch: 312. Validation Loss: 26.468346158663433
# Epoch: 313. Train Loss: 26.133020293712615
# Epoch: 313. Validation Loss: 26.641404459873836
# Epoch: 314. Train Loss: 25.4257680632174
# Epoch: 314. Validation Loss: 27.270155052344005
# Epoch: 315. Train Loss: 25.609262224286795
# Epoch: 315. Validation Loss: 26.325485507647198
# Epoch: 316. Train Loss: 25.454877409338952
# Epoch: 316. Validation Loss: 27.387625972429912
# Epoch: 317. Train Loss: 25.370138220489025
# Epoch: 317. Validation Loss: 25.83015348513921
# Epoch: 318. Train Loss: 25.455264308303594
# Epoch: 318. Validation Loss: 26.748735437790554
# Epoch: 319. Train Loss: 25.805900109559296
# Epoch: 319. Validation Loss: 26.093445161978405
# Epoch: 320. Train Loss: 25.33350044488907
# Epoch: 320. Validation Loss: 26.388068278630573
# Epoch: 321. Train Loss: 25.49983156770468
# Epoch: 321. Validation Loss: 26.7450346549352
# Epoch: 322. Train Loss: 25.87043757662177
# Epoch: 322. Validation Loss: 26.474296063184738
# Epoch: 323. Train Loss: 25.58538948222995
# Epoch: 323. Validation Loss: 26.82665518919627
# Epoch: 324. Train Loss: 25.588286263495682
# Epoch: 324. Validation Loss: 27.921002825101215
# Epoch: 325. Train Loss: 25.49675582200289
# Epoch: 325. Validation Loss: 27.35540657242139
# Epoch: 326. Train Loss: 25.477256413549185
# Epoch: 326. Validation Loss: 26.061658670504887
# Epoch: 327. Train Loss: 25.899731589853765
# Epoch: 327. Validation Loss: 26.392635722955067
# Epoch: 328. Train Loss: 25.349880481511356
# Epoch: 328. Validation Loss: 26.38877233862877
# Epoch: 329. Train Loss: 25.335658141225576
# Epoch: 329. Validation Loss: 26.23406395316124
# Epoch: 330. Train Loss: 25.702954993396997
# Epoch: 330. Validation Loss: 26.16491596897443
# Epoch: 331. Train Loss: 25.23942015245557
# Epoch: 331. Validation Loss: 25.988579759995144
# Epoch: 332. Train Loss: 25.132133290171623
# Epoch: 332. Validation Loss: 26.52935505906741
# Epoch: 333. Train Loss: 25.688658809661867
# Epoch: 333. Validation Loss: 25.608727206786472
# Epoch: 334. Train Loss: 25.746715833991765
# Epoch: 334. Validation Loss: 26.02068967620532
# Epoch: 335. Train Loss: 25.45362572520971
# Epoch: 335. Validation Loss: 26.198361068964005
# Epoch: 336. Train Loss: 25.081765684485436
# Epoch: 336. Validation Loss: 25.75871929526329
# Epoch: 337. Train Loss: 25.3269402988255
# Epoch: 337. Validation Loss: 25.69532746076584
# Epoch: 338. Train Loss: 25.309220076352357
# Epoch: 338. Validation Loss: 25.908587753772736
# Epoch: 339. Train Loss: 25.108854879438876
# Epoch: 339. Validation Loss: 26.820751974980038
# Epoch: 340. Train Loss: 25.432487889379264
# Epoch: 340. Validation Loss: 26.277542461951573
# Epoch: 341. Train Loss: 24.843418584764002
# Epoch: 341. Validation Loss: 26.8106853167216
# Epoch: 342. Train Loss: 25.819692192226647
# Epoch: 342. Validation Loss: 26.0798317193985
# Epoch: 343. Train Loss: 25.1405138194561
# Epoch: 343. Validation Loss: 27.35684284567833
# Epoch: 344. Train Loss: 25.343394646048544
# Epoch: 344. Validation Loss: 26.115074058373768
# Epoch: 345. Train Loss: 25.45942274108529
# Epoch: 345. Validation Loss: 26.204555024703343
# Epoch: 346. Train Loss: 25.513859254866837
# Epoch: 346. Validation Loss: 26.921045849720638
# Epoch: 347. Train Loss: 25.05022810995579
# Epoch: 347. Validation Loss: 26.266990900039673
# Epoch: 348. Train Loss: 25.185994827747344
# Epoch: 348. Validation Loss: 26.334451407194138
# Epoch: 349. Train Loss: 25.7476414360106
# Epoch: 349. Validation Loss: 26.95453358689944
# Epoch: 350. Train Loss: 24.955037140101194
# Epoch: 350. Validation Loss: 27.5689757168293
# Epoch: 351. Train Loss: 25.267046431452037
# Epoch: 351. Validation Loss: 26.762295534213383
# Epoch: 352. Train Loss: 24.919966531544922
# Epoch: 352. Validation Loss: 25.80367609858513
# Epoch: 353. Train Loss: 25.46221343576908
# Epoch: 353. Validation Loss: 25.827344745397568
# Epoch: 354. Train Loss: 25.473408142477275
# Epoch: 354. Validation Loss: 25.669209440549213
# Epoch: 355. Train Loss: 25.04049388729036
# Epoch: 355. Validation Loss: 27.90751000245412
# Epoch: 356. Train Loss: 25.08379857316613
# Epoch: 356. Validation Loss: 27.529791116714478
# Epoch: 357. Train Loss: 25.44986837655306
# Epoch: 357. Validation Loss: 27.15276645620664
# Epoch: 358. Train Loss: 25.407802113890646
# Epoch: 358. Validation Loss: 25.594974358876545
# Epoch: 359. Train Loss: 25.17488744482398
# Epoch: 359. Validation Loss: 26.12136380871137
# Epoch: 360. Train Loss: 25.314650235325097
# Epoch: 360. Validation Loss: 26.821298748254776
# Epoch: 361. Train Loss: 25.075513151288032
# Epoch: 361. Validation Loss: 25.79834109544754
# Epoch: 362. Train Loss: 25.136419714987277
# Epoch: 362. Validation Loss: 26.431701511144638
# Epoch: 363. Train Loss: 25.599110519140957
# Epoch: 363. Validation Loss: 26.1007082760334
# Epoch: 364. Train Loss: 25.454894452542067
# Epoch: 364. Validation Loss: 26.32820560534795
# Epoch: 365. Train Loss: 25.542293500900268
# Epoch: 365. Validation Loss: 26.399978349606197
# Epoch: 366. Train Loss: 25.143430970609188
# Epoch: 366. Validation Loss: 26.478157202402752
# Epoch: 367. Train Loss: 25.148272717744113
# Epoch: 367. Validation Loss: 26.306539118289948
# Epoch: 368. Train Loss: 25.484242071211337
# Epoch: 368. Validation Loss: 27.170466860135395
# Epoch: 369. Train Loss: 25.47456173300743
# Epoch: 369. Validation Loss: 27.512696266174316
# Epoch: 370. Train Loss: 25.12188600599766
# Epoch: 370. Validation Loss: 26.13763823111852
# Epoch: 371. Train Loss: 25.69451435431838
# Epoch: 371. Validation Loss: 25.885702222585678
# Epoch: 372. Train Loss: 25.289015878736972
# Epoch: 372. Validation Loss: 28.301521569490433
# Epoch: 373. Train Loss: 25.380390205979346
# Epoch: 373. Validation Loss: 25.74448999762535
# Epoch: 374. Train Loss: 25.48817409425974
# Epoch: 374. Validation Loss: 26.40106377005577
# Epoch: 375. Train Loss: 25.529339502751828
# Epoch: 375. Validation Loss: 26.376722792784374
# Epoch: 376. Train Loss: 25.138608476519586
# Epoch: 376. Validation Loss: 26.618706434965134
# Epoch: 377. Train Loss: 25.315300488471983
# Epoch: 377. Validation Loss: 26.017712314923603
# Epoch: 378. Train Loss: 24.760082068294288
# Epoch: 378. Validation Loss: 26.368379324674606
# Epoch: 379. Train Loss: 24.84335151910782
# Epoch: 379. Validation Loss: 26.995336671670277
# Epoch: 380. Train Loss: 24.744356273114683
# Epoch: 380. Validation Loss: 26.627779841423035
# Epoch: 381. Train Loss: 24.91829906925559
# Epoch: 381. Validation Loss: 26.689483275016148
# Epoch: 382. Train Loss: 25.204034612327813
# Epoch: 382. Validation Loss: 26.426736841599148
# Epoch: 383. Train Loss: 25.473682536929847
# Epoch: 383. Validation Loss: 26.772635867198307
# Epoch: 384. Train Loss: 24.906101574003696
# Epoch: 384. Validation Loss: 27.083474655946095
# Epoch: 385. Train Loss: 25.541305746883154
# Epoch: 385. Validation Loss: 25.918575555086136
# Epoch: 386. Train Loss: 25.36368345543742
# Epoch: 386. Validation Loss: 26.834917455911636
# Epoch: 387. Train Loss: 25.261567866429687
# Epoch: 387. Validation Loss: 26.846602976322174
# Epoch: 388. Train Loss: 24.884357581287624
# Epoch: 388. Validation Loss: 26.1169231235981
# Epoch: 389. Train Loss: 25.311216216534376
# Epoch: 389. Validation Loss: 26.184355547030766
# Epoch: 390. Train Loss: 24.98372159898281
# Epoch: 390. Validation Loss: 26.060598999261856
# Epoch: 391. Train Loss: 24.975436061620712
# Epoch: 391. Validation Loss: 26.239689876635868
# Epoch: 392. Train Loss: 24.94270890057087
# Epoch: 392. Validation Loss: 26.441620856523514
# Epoch: 393. Train Loss: 25.494982962310313
# Epoch: 393. Validation Loss: 26.710119903087616
# Epoch: 394. Train Loss: 24.887964291125535
# Epoch: 394. Validation Loss: 26.59264211853345
# Epoch: 395. Train Loss: 24.833310361206532
# Epoch: 395. Validation Loss: 26.749832560618717
# Epoch: 396. Train Loss: 25.504142986238
# Epoch: 396. Validation Loss: 25.840726882219315
# Epoch: 397. Train Loss: 25.033206220716238
# Epoch: 397. Validation Loss: 26.497025698423386
# Epoch: 398. Train Loss: 25.122634217888116
# Epoch: 398. Validation Loss: 25.851942201455433
# Epoch: 399. Train Loss: 25.364928436279296
# Epoch: 399. Validation Loss: 25.949262847503025

# %%
iterations = []
imageCounter = 0
# Output_dataloader = DataLoader(trainData, batch_size=1, shuffle=True, drop_last=False)
Output_dataloader = DataLoader(validationData, batch_size=1, shuffle=True, drop_last=False)
with torch.no_grad():
    for dataBatch in Output_dataloader:
        Images, groundTruths, paths = dataBatch
        Images, groundTruths = Images.to(device), groundTruths.to(device)
        outputs = net(Images.view(-1, 2, ImageResoulution, ImageResoulution))

        indexes = []
        outputSegments = np.array(outputs[0].view(6, RegressionSegmentation).cpu())
        for segment in outputSegments:
            indexes.append(np.argmax(segment, axis=0))
        indexes = (np.array(indexes, dtype=np.float32) * RegressionSegmentation) - 1152
        outputPoints = indexes.reshape(3, 2)

        srcPoints = np.array(
            [
                [0, 0],
                [1440, 1440],
                [0, 1440],
            ]
        ).astype(np.float32)
        outputTransform = cv2.getAffineTransform(srcPoints, outputPoints)

        src = Images[0][1][0]
        src = src.cpu().detach().numpy()
        src = cv2.resize(src, (1440, 1440))
        warped = cv2.warpAffine(src, outputTransform, (src.shape[1], src.shape[0]))

        grayImage = np.array(warped * 255, dtype=np.uint8)

        name = paths["src"][0][10:].replace("\\", "")
        cv2.imwrite(f".\\..\\CNNAlignedImages\\Image{name}{imageCounter}.png", grayImage)

        imageCounter += 1

        loss = loss_function(outputs, groundTruths.view(-1, RegressionSegmentation * 6))
        iterations.append({"batch": dataBatch, "outputs": outputPoints, "loss": loss})

# %%
iteration = random.choice(iterations)
im, gt, paths = iteration["batch"]

np.set_printoptions(precision=3, suppress=True)
print(f"loss: {iteration['loss']}")

src = im[0][1]
src = src.cpu().detach().numpy()
src = cv2.resize(src[0], (1440, 1440))

dst = im[0][0]
dst = dst.cpu().detach().numpy()
dst = cv2.resize(dst[0], (1440, 1440))

indexes = []
outputSegments = np.array(gt[0].view(6, RegressionSegmentation).cpu())
for segment in outputSegments:
    indexes.append(np.argmax(segment, axis=0))
indexes = (np.array(indexes, dtype=np.float32) * RegressionSegmentation) - 1152
groundPoints = indexes.reshape(3, 2)

outputPoints = iteration["outputs"]

srcPoints = np.array(
    [
        [0, 0],
        [1440, 1440],
        [0, 1440],
    ]
).astype(np.float32)

fig, axes = plt.subplots(2, 2, figsize=(14, 14))

# Ground Truth
print(outputPoints)
print(groundPoints)

gtTransform = cv2.getAffineTransform(srcPoints, groundPoints)
warped = cv2.warpAffine(src, gtTransform, (1440, 1440))
axes[0][0].imshow(warped)

# Network Result
outputTransform = cv2.getAffineTransform(srcPoints, outputPoints)
warped = cv2.warpAffine(src, outputTransform, (1440, 1440))

axes[1][0].imshow(warped)

# Network Imputs
axes[0][1].imshow(im[0][0].view(ImageResoulution, ImageResoulution))
axes[1][1].imshow(im[0][1].view(ImageResoulution, ImageResoulution))
# Out:
# loss: 24.275903463363647
# [[ -64. -192.]
#  [1472. 1216.]
#  [  64. 1280.]]
# [[   0.  -64.]
#  [1408. 1408.]
#  [ -64. 1408.]]

# %%
points = np.mat(
    [
        [0, 0, 1],
        [1440, 1440, 1],
        [0, 1440, 1],
    ]
)

print(points[:, 0:-1].flatten())
print(points[:, 0:-1])
# Out:
# [[   0    0 1440 1440    0 1440]]
# [[   0    0]
#  [1440 1440]
#  [   0 1440]]
