# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

from PIL import Image, ImageOps
import os
import json
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms

import torch.optim as optim

import cv2

import random
import numpy as np

import matplotlib.pyplot as plt

# %%
if torch.cuda.is_available():
    device = torch.device("cuda:0")
    print("Running on the GPU")
else:
    device = torch.device("cpu")
    print("Running on the CPU")
# Out:
# Running on the GPU

# %%
#### DEFINE DataLoader ####
class data(Dataset):
    def __init__(self, path, generatateCount = 20):
        self.path = path
        self.Items = []
        self.generateCount = generatateCount

        convert_tensor = transforms.ToTensor()
        convert_float = transforms.ConvertImageDtype(torch.float)

        self.files = os.listdir(path)

        for ML_Record in self.files:
            DatasetItem = json.load(open(os.path.join(self.path, ML_Record)))
            for i in range(0, generatateCount):

                src = cv2.imread(DatasetItem["src"], cv2.IMREAD_GRAYSCALE)
                dst = cv2.imread(DatasetItem["dst"], cv2.IMREAD_GRAYSCALE)
                originalTransfrom = np.matrix(DatasetItem["transformation"])

                if i != 0:
                    translationX = random.uniform(-100, 100)
                    translationY = random.uniform(100, 80)
                    scale = random.uniform(0.8, 1.2)
                    rotation = random.uniform(-5, 5)

                    AugmentingMat = np.mat([[scale, 0.0, translationX], [0.0, scale, translationY], [0.0, 0.0, 1.0]], dtype=np.float32)
                    rotationMat = cv2.getRotationMatrix2D((src.shape[1] // 2, src.shape[0] // 2), rotation, 1)
                    AugmentingMat = np.matmul(np.vstack([rotationMat, [0, 0, 1]]), AugmentingMat, dtype=np.float32)

                    invertedAugmentingMat = np.mat(cv2.invertAffineTransform(AugmentingMat[0:-1, :]))
                    invertedAugmentingMat = np.vstack([invertedAugmentingMat, [0, 0, 1]])

                    GeneratedTransform = np.matmul(originalTransfrom, invertedAugmentingMat)
                    src = cv2.warpAffine(src, AugmentingMat[0:-1, :], (1440, 1440))
                else:
                    GeneratedTransform = originalTransfrom

                points = [
                    [0, 0, 1],
                    [1440, 1440, 1],
                    [0, 1440, 1],
                ]
                warpedPoints = np.matmul(points, GeneratedTransform.transpose(), dtype=np.float32)
                
                warped = cv2.resize(src, (128, 128))
                dst = cv2.resize(dst, (128, 128))

                stacked = torch.stack((convert_tensor(dst), convert_tensor(warped)))
                paths = {"src": DatasetItem["src"], "dst": DatasetItem["dst"]}
                self.Items.append((stacked, torch.from_numpy(warpedPoints[:, 0:-1].flatten()), paths))

    # the function returns length of data
    def __len__(self):
        return len(self.Items)

    # gives one item at a time
    def __getitem__(self, index):
        return self.Items[index]

# %%
#### DEFINE Neural Network ####
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        self._to_linear = None

        # 2 input image channel, 64 output channels, 5x5 square convolution
        # kernel
        self.conv1 = nn.Conv2d(2, 64, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)

        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv4 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)

        self.conv5 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv6 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)

        self.conv7 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)
        self.conv8 = nn.Conv2d(64, 64, kernel_size=3, stride=1, padding=1)

        self.fc9 = nn.Linear(16384, 1024)

        self.fc10 = nn.Linear(1024, 6)

        self.dropout2 = nn.Dropout(0.2)

    def convs(self, x):
        # max pooling over 2x2
        # two conv layers
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))

        # max pooling
        x = F.max_pool2d(x, 2)

        # two conv layers
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))

        # max pooling
        x = F.max_pool2d(x, 2)

        # two conv layers
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))

        # max pooling
        x = F.max_pool2d(x, 2)

        # two conv layers
        x = F.relu(self.conv7(x))
        x = F.relu(self.conv8(x))

        return x

    def forward(self, x):

        x = self.convs(x)
        x = x.view(-1, x[0].shape[0] * x[0].shape[1] * x[0].shape[2])

        # two linear layers
        x = F.relu(self.fc9(x))
        x = self.dropout2(x)
        x = self.fc10(x)

        return x

# %%
#### Create data ####
trainData = data(".\\..\\data03\MachineData\TrainSet", generatateCount=10)
print(len(trainData))
validationData = data(".\\..\\data03\MachineData\ValidationSet", generatateCount=10)
print(len(validationData))
# Out:
# 2240
# 340

# %%
#### Define parameters ####
BatchSize = 32
Epochs = 300
BatchLogCount = 4
LearningRate = 0.001
WeightDecay = 0.0000001

# %%
from torch.utils.tensorboard import SummaryWriter

# writer = SummaryWriter(f"runs/DPA_23.2_MultiplePose_Classification_v1.0.0.7 BatchSize:{BatchSize}, Epochs:{Epochs}, LearningRate:{LearningRate}, WeightDecay:{WeightDecay}")
writer = SummaryWriter(f"runs/DPA_23.2_MultiplePose_Regression_v1.0.0.19_LearningRate_{LearningRate}_WeightDecay_{WeightDecay}")

train_dataloader = DataLoader(trainData, batch_size=BatchSize, shuffle=True, drop_last=False)
val_dataloader = DataLoader(validationData, batch_size=BatchSize, shuffle=True, drop_last=False)
net = Net().to(device)
loss_function = nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=LearningRate, weight_decay=WeightDecay)

example_images, example_groundTruths, _ = iter(train_dataloader).next()
writer.add_graph(net, example_images.to(device).view(-1, 2, 128, 128))

train_set_len = len(trainData)
validation_set_len = len(validationData)
# Learning
for epoch in range(Epochs):
    running_loss = 0.0
    epoch_loss = 0.0
    batchCount = 0
    for i, dataBatch in enumerate(train_dataloader):
        Images, groundTruths, _ = dataBatch
        Images, groundTruths = Images.to(device), groundTruths.to(device)

        optimizer.zero_grad()

        outputs = net(Images.view(-1, 2, 128, 128))

        loss = loss_function(outputs, groundTruths.view(-1, 6))
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        epoch_loss += loss.item()
        batchCount += 1

        if (i + 1) % BatchLogCount == 0:
            writer.add_scalar("Training loss", running_loss / BatchLogCount, (train_set_len * epoch) + (i * BatchSize))
            running_loss = 0.0

    # Validation
    with torch.no_grad():
        ValidationLoss = 0.0
        ValidationBatchCount = 0
        for k, (Images, groundTruths, _) in enumerate(val_dataloader):
            Images, groundTruths = Images.to(device), groundTruths.to(device)
            outputs = net(Images.view(-1, 2, 128, 128))
            loss = loss_function(outputs, groundTruths.view(-1, 6))
            ValidationLoss += loss.item()
            ValidationBatchCount += 1

    writer.add_scalars(f'Loss/Epoch', {
    'Validation loss': ValidationLoss / ValidationBatchCount,
    'Train loss': epoch_loss / batchCount,
    }, epoch)

    # writer.add_scalar("Validation loss / Epoch", ValidationLoss / ValidationBatchCount, epoch)
    # writer.add_scalar("Train loss / Epoch", epoch_loss / batchCount, epoch)

    print(f"Epoch: {epoch}. Train Loss: {epoch_loss / batchCount}")
    print(f"Epoch: {epoch}. Validation Loss: {ValidationLoss / ValidationBatchCount}")
# Out:
# Epoch: 0. Train Loss: 158574.70334821427
# Epoch: 0. Validation Loss: 50276.64382102273
# Epoch: 1. Train Loss: 39610.3142578125
# Epoch: 1. Validation Loss: 35821.36061789773
# Epoch: 2. Train Loss: 34842.88568638393
# Epoch: 2. Validation Loss: 33820.550603693184
# Epoch: 3. Train Loss: 34762.531529017855
# Epoch: 3. Validation Loss: 33331.23934659091
# Epoch: 4. Train Loss: 36515.088588169645
# Epoch: 4. Validation Loss: 31720.594460227272
# Epoch: 5. Train Loss: 32644.91378348214
# Epoch: 5. Validation Loss: 46455.18465909091
# Epoch: 6. Train Loss: 33915.58546316964
# Epoch: 6. Validation Loss: 35552.523615056816
# Epoch: 7. Train Loss: 31393.4923828125
# Epoch: 7. Validation Loss: 29296.99822443182
# Epoch: 8. Train Loss: 30213.38260323661
# Epoch: 8. Validation Loss: 27784.596413352272
# Epoch: 9. Train Loss: 31055.81958705357
# Epoch: 9. Validation Loss: 24718.66974431818
# Epoch: 10. Train Loss: 27196.672014508928
# Epoch: 10. Validation Loss: 30660.75603693182
# Epoch: 11. Train Loss: 28613.0244140625
# Epoch: 11. Validation Loss: 27074.251065340908
# Epoch: 12. Train Loss: 24123.681291852678
# Epoch: 12. Validation Loss: 18287.033913352272
# Epoch: 13. Train Loss: 25128.127287946427
# Epoch: 13. Validation Loss: 20241.482865767044
# Epoch: 14. Train Loss: 22441.034319196428
# Epoch: 14. Validation Loss: 19800.784889914772
# Epoch: 15. Train Loss: 20962.70633370536
# Epoch: 15. Validation Loss: 23138.442471590908
# Epoch: 16. Train Loss: 18922.121219308036
# Epoch: 16. Validation Loss: 17511.357688210228
# Epoch: 17. Train Loss: 17934.907352120536
# Epoch: 17. Validation Loss: 18858.635209517044
# Epoch: 18. Train Loss: 19935.448842075893
# Epoch: 18. Validation Loss: 18169.719460227272
# Epoch: 19. Train Loss: 16009.400181361607
# Epoch: 19. Validation Loss: 22173.976029829544
# Epoch: 20. Train Loss: 15670.839578683035
# Epoch: 20. Validation Loss: 14831.798561789772
# Epoch: 21. Train Loss: 15906.785421316965
# Epoch: 21. Validation Loss: 16665.50372869318
# Epoch: 22. Train Loss: 14253.82744140625
# Epoch: 22. Validation Loss: 15780.54598721591
# Epoch: 23. Train Loss: 13875.920689174107
# Epoch: 23. Validation Loss: 16399.228959517044
# Epoch: 24. Train Loss: 13160.59877232143
# Epoch: 24. Validation Loss: 14859.425958806818
# Epoch: 25. Train Loss: 12651.714857700892
# Epoch: 25. Validation Loss: 17585.975852272728
# Epoch: 26. Train Loss: 10539.968526785715
# Epoch: 26. Validation Loss: 14748.081409801136
# Epoch: 27. Train Loss: 11187.705845424107
# Epoch: 27. Validation Loss: 16599.739701704544
# Epoch: 28. Train Loss: 10189.135567801339
# Epoch: 28. Validation Loss: 15885.62881747159
# Epoch: 29. Train Loss: 11284.211188616071
# Epoch: 29. Validation Loss: 15438.459428267046
# Epoch: 30. Train Loss: 9384.320675223214
# Epoch: 30. Validation Loss: 15055.16024502841
# Epoch: 31. Train Loss: 10493.590080915179
# Epoch: 31. Validation Loss: 15065.39071377841
# Epoch: 32. Train Loss: 8552.649623325893
# Epoch: 32. Validation Loss: 14534.001598011364
# Epoch: 33. Train Loss: 8925.015834263393
# Epoch: 33. Validation Loss: 16574.999378551136
# Epoch: 34. Train Loss: 8060.530838448661
# Epoch: 34. Validation Loss: 18554.282492897728
# Epoch: 35. Train Loss: 8939.262506975447
# Epoch: 35. Validation Loss: 14704.30282315341
# Epoch: 36. Train Loss: 8066.979827008929
# Epoch: 36. Validation Loss: 15384.236860795454
# Epoch: 37. Train Loss: 7951.886579241072
# Epoch: 37. Validation Loss: 15864.83797940341
# Epoch: 38. Train Loss: 7669.2496303013395
# Epoch: 38. Validation Loss: 18625.643909801136
# Epoch: 39. Train Loss: 7073.948876953125
# Epoch: 39. Validation Loss: 15410.102805397728
# Epoch: 40. Train Loss: 7212.079248046875
# Epoch: 40. Validation Loss: 16316.92578125
# Epoch: 41. Train Loss: 7075.290736607143
# Epoch: 41. Validation Loss: 19826.69158380682
# Epoch: 42. Train Loss: 6476.46892438616
# Epoch: 42. Validation Loss: 15136.177911931818
# Epoch: 43. Train Loss: 7823.26123046875
# Epoch: 43. Validation Loss: 15721.50301846591
# Epoch: 44. Train Loss: 7219.13427734375
# Epoch: 44. Validation Loss: 15136.099964488636
# Epoch: 45. Train Loss: 6377.377845982143
# Epoch: 45. Validation Loss: 15519.059836647728
# Epoch: 46. Train Loss: 6627.5259974888395
# Epoch: 46. Validation Loss: 14411.671342329546
# Epoch: 47. Train Loss: 6407.215478515625
# Epoch: 47. Validation Loss: 17698.748668323864
# Epoch: 48. Train Loss: 6058.730336216518
# Epoch: 48. Validation Loss: 15743.206498579546
# Epoch: 49. Train Loss: 6923.281762695313
# Epoch: 49. Validation Loss: 22222.06427556818
# Epoch: 50. Train Loss: 8039.36424734933
# Epoch: 50. Validation Loss: 15120.917169744318
# Epoch: 51. Train Loss: 6629.288480050223
# Epoch: 51. Validation Loss: 17115.163174715908
# Epoch: 52. Train Loss: 6804.739697265625
# Epoch: 52. Validation Loss: 14539.550159801136
# Epoch: 53. Train Loss: 5831.85187639509
# Epoch: 53. Validation Loss: 17472.991832386364
# Epoch: 54. Train Loss: 6171.712482561384
# Epoch: 54. Validation Loss: 15504.33877840909
# Epoch: 55. Train Loss: 5191.626220703125
# Epoch: 55. Validation Loss: 14782.005060369318
# Epoch: 56. Train Loss: 5314.121013532366
# Epoch: 56. Validation Loss: 18031.978515625
# Epoch: 57. Train Loss: 5613.7557407924105
# Epoch: 57. Validation Loss: 15400.85245028409
# Epoch: 58. Train Loss: 6627.477465820312
# Epoch: 58. Validation Loss: 15246.928444602272
# Epoch: 59. Train Loss: 6037.115778459822
# Epoch: 59. Validation Loss: 14361.89737215909
# Epoch: 60. Train Loss: 4918.494635881696
# Epoch: 60. Validation Loss: 14456.533380681818
# Epoch: 61. Train Loss: 5408.749257114955
# Epoch: 61. Validation Loss: 18822.548206676136
# Epoch: 62. Train Loss: 7521.764515904018
# Epoch: 62. Validation Loss: 15399.34286221591
# Epoch: 63. Train Loss: 4917.3738978794645
# Epoch: 63. Validation Loss: 15750.282581676136
# Epoch: 64. Train Loss: 5666.624093191965
# Epoch: 64. Validation Loss: 16603.881569602272
# Epoch: 65. Train Loss: 5524.081874302456
# Epoch: 65. Validation Loss: 16124.592329545454
# Epoch: 66. Train Loss: 4961.192815290178
# Epoch: 66. Validation Loss: 15983.071644176136
# Epoch: 67. Train Loss: 4797.098434012277
# Epoch: 67. Validation Loss: 14915.651544744318
# Epoch: 68. Train Loss: 4252.829031808035
# Epoch: 68. Validation Loss: 14714.223277698864
# Epoch: 69. Train Loss: 4274.965614536831
# Epoch: 69. Validation Loss: 14763.408025568182
# Epoch: 70. Train Loss: 4842.176238141741
# Epoch: 70. Validation Loss: 15004.445134943182
# Epoch: 71. Train Loss: 4803.175355747768
# Epoch: 71. Validation Loss: 15055.112837357954
# Epoch: 72. Train Loss: 4752.048067801339
# Epoch: 72. Validation Loss: 15817.282670454546
# Epoch: 73. Train Loss: 4552.164146205357
# Epoch: 73. Validation Loss: 14594.260564630682
# Epoch: 74. Train Loss: 4315.009273856027
# Epoch: 74. Validation Loss: 14749.413707386364
# Epoch: 75. Train Loss: 4378.687398856026
# Epoch: 75. Validation Loss: 15991.90145596591
# Epoch: 76. Train Loss: 5273.015443638393
# Epoch: 76. Validation Loss: 15824.20889559659
# Epoch: 77. Train Loss: 4132.664620535715
# Epoch: 77. Validation Loss: 14742.45498934659
# Epoch: 78. Train Loss: 4087.403351702009
# Epoch: 78. Validation Loss: 15566.033558238636
# Epoch: 79. Train Loss: 4117.846257672991
# Epoch: 79. Validation Loss: 15345.15518465909
# Epoch: 80. Train Loss: 4482.075938197545
# Epoch: 80. Validation Loss: 19283.289595170456
# Epoch: 81. Train Loss: 4486.014592633928
# Epoch: 81. Validation Loss: 16514.967151988636
# Epoch: 82. Train Loss: 4867.409430803571
# Epoch: 82. Validation Loss: 16350.912553267046
# Epoch: 83. Train Loss: 4912.753874860491
# Epoch: 83. Validation Loss: 21763.317294034092
# Epoch: 84. Train Loss: 4642.60108468192
# Epoch: 84. Validation Loss: 15889.344105113636
# Epoch: 85. Train Loss: 4111.053805106027
# Epoch: 85. Validation Loss: 15479.12393465909
# Epoch: 86. Train Loss: 3922.759908621652
# Epoch: 86. Validation Loss: 14700.875266335228
# Epoch: 87. Train Loss: 4585.192644391741
# Epoch: 87. Validation Loss: 14637.893377130682
# Epoch: 88. Train Loss: 4739.481846400669
# Epoch: 88. Validation Loss: 15654.155806107954
# Epoch: 89. Train Loss: 4122.658719308036
# Epoch: 89. Validation Loss: 15856.929066051136
# Epoch: 90. Train Loss: 3934.354293387277
# Epoch: 90. Validation Loss: 14367.53182705966
# Epoch: 91. Train Loss: 3849.291796875
# Epoch: 91. Validation Loss: 16212.244673295454
# Epoch: 92. Train Loss: 4894.992525809152
# Epoch: 92. Validation Loss: 15301.17764559659
# Epoch: 93. Train Loss: 4757.358921595982
# Epoch: 93. Validation Loss: 14978.832830255682
# Epoch: 94. Train Loss: 4063.839599609375
# Epoch: 94. Validation Loss: 16320.879350142046
# Epoch: 95. Train Loss: 4000.173716517857
# Epoch: 95. Validation Loss: 15010.9287109375
# Epoch: 96. Train Loss: 4100.808639090402
# Epoch: 96. Validation Loss: 15687.687144886364
# Epoch: 97. Train Loss: 4303.585864257812
# Epoch: 97. Validation Loss: 17037.587002840908
# Epoch: 98. Train Loss: 3705.552800641741
# Epoch: 98. Validation Loss: 14726.676313920454
# Epoch: 99. Train Loss: 3526.188933454241
# Epoch: 99. Validation Loss: 15904.672141335228
# Epoch: 100. Train Loss: 3887.6015869140624
# Epoch: 100. Validation Loss: 16251.873224431818
# Epoch: 101. Train Loss: 3630.5318010602678
# Epoch: 101. Validation Loss: 14632.307084517046
# Epoch: 102. Train Loss: 3348.424183872768
# Epoch: 102. Validation Loss: 15515.95498934659
# Epoch: 103. Train Loss: 3823.116135951451
# Epoch: 103. Validation Loss: 19958.987926136364
# Epoch: 104. Train Loss: 4075.1203543526785
# Epoch: 104. Validation Loss: 18192.35955255682
# Epoch: 105. Train Loss: 3182.003909737723
# Epoch: 105. Validation Loss: 14301.409623579546
# Epoch: 106. Train Loss: 3246.0567138671877
# Epoch: 106. Validation Loss: 13926.093394886364
# Epoch: 107. Train Loss: 3754.4607142857144
# Epoch: 107. Validation Loss: 14103.126420454546
# Epoch: 108. Train Loss: 3274.2391217912946
# Epoch: 108. Validation Loss: 14573.40616122159
# Epoch: 109. Train Loss: 3649.7333426339287
# Epoch: 109. Validation Loss: 17440.41228693182
# Epoch: 110. Train Loss: 3739.0874372209823
# Epoch: 110. Validation Loss: 15329.313654119318
# Epoch: 111. Train Loss: 3259.1547956194195
# Epoch: 111. Validation Loss: 14795.835582386364
# Epoch: 112. Train Loss: 3463.8452218191965
# Epoch: 112. Validation Loss: 14634.360706676136
# Epoch: 113. Train Loss: 3227.453512137277
# Epoch: 113. Validation Loss: 15677.721413352272
# Epoch: 114. Train Loss: 3862.2581124441963
# Epoch: 114. Validation Loss: 14840.6416015625
# Epoch: 115. Train Loss: 3660.9780343191965
# Epoch: 115. Validation Loss: 14594.003373579546
# Epoch: 116. Train Loss: 3248.435072544643
# Epoch: 116. Validation Loss: 14280.315784801136
# Epoch: 117. Train Loss: 3380.2649274553573
# Epoch: 117. Validation Loss: 14871.415216619318
# Epoch: 118. Train Loss: 3646.942166573661
# Epoch: 118. Validation Loss: 16809.844637784092
# Epoch: 119. Train Loss: 3466.572771344866
# Epoch: 119. Validation Loss: 14560.742720170454
# Epoch: 120. Train Loss: 3412.206685965402
# Epoch: 120. Validation Loss: 14903.020241477272
# Epoch: 121. Train Loss: 3388.8267595563616
# Epoch: 121. Validation Loss: 15726.520862926136
# Epoch: 122. Train Loss: 3401.0171665736607
# Epoch: 122. Validation Loss: 15089.177734375
# Epoch: 123. Train Loss: 3193.0042271205357
# Epoch: 123. Validation Loss: 15511.195046164772
# Epoch: 124. Train Loss: 3412.9955636160716
# Epoch: 124. Validation Loss: 15667.703125
# Epoch: 125. Train Loss: 3389.703820800781
# Epoch: 125. Validation Loss: 14215.313920454546
# Epoch: 126. Train Loss: 3873.0368059430803
# Epoch: 126. Validation Loss: 15311.396928267046
# Epoch: 127. Train Loss: 3496.725474330357
# Epoch: 127. Validation Loss: 15304.608575994318
# Epoch: 128. Train Loss: 3259.529084123884
# Epoch: 128. Validation Loss: 14873.372602982954
# Epoch: 129. Train Loss: 3100.483269391741
# Epoch: 129. Validation Loss: 15113.884144176136
# Epoch: 130. Train Loss: 3473.6164655412945
# Epoch: 130. Validation Loss: 14660.771040482954
# Epoch: 131. Train Loss: 3911.6860595703124
# Epoch: 131. Validation Loss: 16678.314719460228
# Epoch: 132. Train Loss: 2974.542644391741
# Epoch: 132. Validation Loss: 14519.681374289772
# Epoch: 133. Train Loss: 3316.084127371652
# Epoch: 133. Validation Loss: 13873.91415127841
# Epoch: 134. Train Loss: 3406.8031703404017
# Epoch: 134. Validation Loss: 14934.056463068182
# Epoch: 135. Train Loss: 3900.942578125
# Epoch: 135. Validation Loss: 16006.9345703125
# Epoch: 136. Train Loss: 3518.6862810407365
# Epoch: 136. Validation Loss: 15560.965287642046
# Epoch: 137. Train Loss: 3262.76781703404
# Epoch: 137. Validation Loss: 14434.765891335228
# Epoch: 138. Train Loss: 3241.5815987723213
# Epoch: 138. Validation Loss: 14864.4921875
# Epoch: 139. Train Loss: 3302.6506277901785
# Epoch: 139. Validation Loss: 15173.907581676136
# Epoch: 140. Train Loss: 3146.0639020647322
# Epoch: 140. Validation Loss: 15380.872780539772
# Epoch: 141. Train Loss: 3379.7435076032366
# Epoch: 141. Validation Loss: 13988.05752840909
# Epoch: 142. Train Loss: 3369.0581612723213
# Epoch: 142. Validation Loss: 15069.354048295454
# Epoch: 143. Train Loss: 3010.9855015345984
# Epoch: 143. Validation Loss: 13749.61239346591
# Epoch: 144. Train Loss: 4231.007646833147
# Epoch: 144. Validation Loss: 14265.072798295454
# Epoch: 145. Train Loss: 2877.9995099748885
# Epoch: 145. Validation Loss: 15054.93563565341
# Epoch: 146. Train Loss: 2989.7574951171873
# Epoch: 146. Validation Loss: 14604.383256392046
# Epoch: 147. Train Loss: 3347.4688267299107
# Epoch: 147. Validation Loss: 15938.972034801136
# Epoch: 148. Train Loss: 2841.6291939871653
# Epoch: 148. Validation Loss: 14866.556285511364
# Epoch: 149. Train Loss: 2945.858163016183
# Epoch: 149. Validation Loss: 13907.42098721591
# Epoch: 150. Train Loss: 3361.277144949777
# Epoch: 150. Validation Loss: 16208.022017045454
# Epoch: 151. Train Loss: 3217.4276576450893
# Epoch: 151. Validation Loss: 14390.65909090909
# Epoch: 152. Train Loss: 3227.2169764927457
# Epoch: 152. Validation Loss: 13770.306019176136
# Epoch: 153. Train Loss: 3791.811683872768
# Epoch: 153. Validation Loss: 15099.127308238636
# Epoch: 154. Train Loss: 3005.676858956473
# Epoch: 154. Validation Loss: 14185.66299715909
# Epoch: 155. Train Loss: 3432.447072056362
# Epoch: 155. Validation Loss: 15180.207652698864
# Epoch: 156. Train Loss: 3366.069142368862
# Epoch: 156. Validation Loss: 14249.907936789772
# Epoch: 157. Train Loss: 2828.1669102260043
# Epoch: 157. Validation Loss: 14195.966796875
# Epoch: 158. Train Loss: 3012.330161830357
# Epoch: 158. Validation Loss: 15191.614080255682
# Epoch: 159. Train Loss: 3157.450350516183
# Epoch: 159. Validation Loss: 15816.734730113636
# Epoch: 160. Train Loss: 3060.036129324777
# Epoch: 160. Validation Loss: 14757.9619140625
# Epoch: 161. Train Loss: 2647.816027832031
# Epoch: 161. Validation Loss: 14815.048473011364
# Epoch: 162. Train Loss: 3414.5870762416293
# Epoch: 162. Validation Loss: 14542.1904296875
# Epoch: 163. Train Loss: 2830.5187255859373
# Epoch: 163. Validation Loss: 15043.911665482954
# Epoch: 164. Train Loss: 2977.188790457589
# Epoch: 164. Validation Loss: 15587.66592684659
# Epoch: 165. Train Loss: 3572.906710379464
# Epoch: 165. Validation Loss: 15519.117365056818
# Epoch: 166. Train Loss: 3068.284695870536
# Epoch: 166. Validation Loss: 14456.408913352272
# Epoch: 167. Train Loss: 2887.7745901925223
# Epoch: 167. Validation Loss: 15822.230113636364
# Epoch: 168. Train Loss: 4003.9131243024553
# Epoch: 168. Validation Loss: 13610.865056818182
# Epoch: 169. Train Loss: 2959.6063284737725
# Epoch: 169. Validation Loss: 14922.083629261364
# Epoch: 170. Train Loss: 2902.19345703125
# Epoch: 170. Validation Loss: 15323.231267755682
# Epoch: 171. Train Loss: 2891.9797241210936
# Epoch: 171. Validation Loss: 14269.236061789772
# Epoch: 172. Train Loss: 2764.7988438197544
# Epoch: 172. Validation Loss: 14819.34756747159
# Epoch: 173. Train Loss: 2593.7596383231025
# Epoch: 173. Validation Loss: 15849.654563210228
# Epoch: 174. Train Loss: 3441.3397617885043
# Epoch: 174. Validation Loss: 16490.316139914772
# Epoch: 175. Train Loss: 3685.074687848772
# Epoch: 175. Validation Loss: 14768.282759232954
# Epoch: 176. Train Loss: 2806.4607962472096
# Epoch: 176. Validation Loss: 14949.772283380682
# Epoch: 177. Train Loss: 2823.4056361607145
# Epoch: 177. Validation Loss: 16078.459250710228
# Epoch: 178. Train Loss: 3225.8980451311386
# Epoch: 178. Validation Loss: 13389.830788352272
# Epoch: 179. Train Loss: 3109.176611328125
# Epoch: 179. Validation Loss: 14630.222922585228
# Epoch: 180. Train Loss: 2750.2626796177456
# Epoch: 180. Validation Loss: 15618.741743607954
# Epoch: 181. Train Loss: 2689.8335030691965
# Epoch: 181. Validation Loss: 14085.711470170454
# Epoch: 182. Train Loss: 2665.826145717076
# Epoch: 182. Validation Loss: 14872.161399147728
# Epoch: 183. Train Loss: 2985.7777186802455
# Epoch: 183. Validation Loss: 13963.70712002841
# Epoch: 184. Train Loss: 2540.9321847098213
# Epoch: 184. Validation Loss: 15085.740944602272
# Epoch: 185. Train Loss: 2774.8773472377234
# Epoch: 185. Validation Loss: 13541.21573153409
# Epoch: 186. Train Loss: 3221.223613630022
# Epoch: 186. Validation Loss: 15402.677024147728
# Epoch: 187. Train Loss: 2712.5816789899554
# Epoch: 187. Validation Loss: 14817.764382102272
# Epoch: 188. Train Loss: 2644.358286830357
# Epoch: 188. Validation Loss: 15397.269264914772
# Epoch: 189. Train Loss: 3147.5476893833707
# Epoch: 189. Validation Loss: 15595.09676846591
# Epoch: 190. Train Loss: 2774.7856201171876
# Epoch: 190. Validation Loss: 15498.295720880682
# Epoch: 191. Train Loss: 2776.4221400669644
# Epoch: 191. Validation Loss: 14023.660688920454
# Epoch: 192. Train Loss: 2496.5675537109373
# Epoch: 192. Validation Loss: 14512.695578835228
# Epoch: 193. Train Loss: 2631.038174874442
# Epoch: 193. Validation Loss: 14852.49813565341
# Epoch: 194. Train Loss: 2956.488197544643
# Epoch: 194. Validation Loss: 14030.352982954546
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15736/3705367948.py in <module>
#      32         optimizer.step()
#      33
# ---> 34         running_loss += loss.item()
#      35         epoch_loss += loss.item()
#      36         batchCount += 1
#
# KeyboardInterrupt:

# %%
validationData = data(".\\..\\data03\MachineData\ValidationSet", generatateCount=1)
val_dataloader = DataLoader(validationData, batch_size=1, shuffle=True, drop_last=False)
iterations = []
imageCounter = 0
with torch.no_grad():
    for dataBatch in val_dataloader:
        Images, groundTruths, paths = dataBatch
        Images, groundTruths = Images.to(device), groundTruths.to(device)
        outputs = net(Images.view(-1, 2, 128, 128)) 

        # writing on disk for demo
        # srcPath = paths["src"][0]
        # dstPath = paths["dst"][0]
        # src = cv2.imread(srcPath, cv2.IMREAD_ANYCOLOR)
        # dst = cv2.imread(dstPath, cv2.IMREAD_ANYCOLOR)    
        outputPoints = np.array(outputs[0].view(3,2).cpu()) 
        srcPoints = np.array([ [0, 0], [1440, 1440], [0, 1440], ]).astype(np.float32)
        outputTransform = cv2.getAffineTransform(srcPoints, outputPoints)

        src = Images[0][1]
        src = src.cpu().detach().numpy()
        src = cv2.resize(src[0], (1440, 1440))
        warped = cv2.warpAffine(src, outputTransform, (src.shape[1], src.shape[0]))
        grayImage = np.array(warped * 255, dtype=np.uint8)

        name = paths["src"][0][10:].replace("\\", "")
        cv2.imwrite(f".\\..\\CNNAlignedImages\\Image{name}{imageCounter}.png", grayImage)

        imageCounter += 1

        loss = loss_function(outputs, groundTruths.view(-1, 6))
        iterations.append({"batch": dataBatch, "outputs": outputPoints, "loss": loss})

# %%
iteration = random.choice(iterations)
im, gt, paths = iteration["batch"]

np.set_printoptions(precision=3, suppress=True)
print(f"loss: {iteration['loss']}")

src = im[0][1]
src = src.cpu().detach().numpy()
src = cv2.resize(src[0], (1440, 1440))

dst = im[0][0]
dst = dst.cpu().detach().numpy()
dst = cv2.resize(dst[0], (1440, 1440))

groundPoints = np.array(gt.view(3,2))
outputPoints = iteration['outputs']
srcPoints = np.array(
    [
        [0, 0],
        [1440, 1440],
        [0, 1440],
    ]
).astype(np.float32)

fig, axes = plt.subplots(2, 2, figsize=(14, 14))

# Ground Truth
print(outputPoints)
print(groundPoints)

gtTransform = cv2.getAffineTransform(srcPoints, groundPoints)
warped = cv2.warpAffine(src, gtTransform, (1440, 1440))
axes[0][0].imshow(warped)

# Network Result
outputTransform = cv2.getAffineTransform(srcPoints, outputPoints)
warped = cv2.warpAffine(src, outputTransform, (1440, 1440))

axes[1][0].imshow(warped)

# Network Imputs
axes[0][1].imshow(im[0][0].view(128, 128))
axes[1][1].imshow(im[0][1].view(128, 128))
# Out:
# loss: 4035.716552734375
# [[  61.428  304.821]
#  [1432.92  1396.91 ]
#  [  -6.044 1594.467]]
# [[  47.195  350.578]
#  [1354.888 1319.15 ]
#  [  -8.788 1495.599]]

# %%
points = np.mat(
    [
        [0, 0, 1],
        [1440, 1440, 1],
        [0, 1440, 1],
    ]
)

print(points[:, 0:-1].flatten())
print(points[:, 0:-1])
# Out:
# [[   0    0 1440 1440    0 1440]]
# [[   0    0]
#  [1440 1440]
#  [   0 1440]]
